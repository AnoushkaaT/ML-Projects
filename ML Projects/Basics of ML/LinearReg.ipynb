# %% [markdown]
# Illustration of Linear Regression Model

# %%
student<-read.csv("/content/students.csv")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '/content/students.csv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("/content/students.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %% [markdown]
# Data pre-processing

# %%
print(summary(student))
# Out:
# Error in eval(expr, envir, enclos): object 'student' not found
# Traceback:
#
# 1. print(summary(student))
# 2. summary(student)

# %%
print(head(student))

# %% [markdown]
# Data Modelling - Linear Regression Model

# %%
model<-lm(Scores~Hours,data=student)

# %%
print(summary(model))

# %%
plot.new()
plot(student$Hours,student$Scores,main="Scatterplot")

# %%
print(coefficients(model))

# %%
print(cor(student$Hours,student$Scores))

# %%
p<-as.data.frame(9.25)
colnames(p)<-"Hours"

# %%
prediction<-predict(model,newdata=p)
print(prediction)
